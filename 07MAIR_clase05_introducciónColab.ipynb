# %%
#API para comunicar Google Colab con Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
#Listo el contenido del raiz de mi Drive
# !ls "/content/drive/My Drive/"
# Out:
# '[07MAIR_04_A_2018-19] Actividad1_corrección_1conv'  'Colab Notebooks'	 VIU
# 'Actividad 1'					      HOLA.gdoc
# 'Cesión Derechos Imagen VIU.docx'		      MAIR_MARKETING

# %%
# Descargo un dataset
# !wget https://github.com/pcsanwald/kaggle-titanic.git -P "/content/drive/My Drive/"

# %%
# !ls "/content/drive/My Drive/"
# Out:
# '[07MAIR_04_A_2018-19] Actividad1_corrección_1conv'   HOLA.gdoc
# 'Actividad 1'					      kaggle-titanic.git
# 'Cesión Derechos Imagen VIU.docx'		      MAIR_MARKETING
# 'Colab Notebooks'				      VIU

# %%
# !rm '/content/drive/My Drive/kaggle-titanic.git'

# %%
# !ls '/content/drive/My Drive/'
# Out:
# '[07MAIR_04_A_2018-19] Actividad1_corrección_1conv'  'Colab Notebooks'	 VIU
# 'Actividad 1'					      HOLA.gdoc
# 'Cesión Derechos Imagen VIU.docx'		      MAIR_MARKETING

# %%
#MUY IMPORTANTE PARA LA ACTIVIDAD!!! Referenciar todo a un directorio base
BASE_FOLDER = '/content/drive/My Drive/Master IA/07MAIR/Actividad1_DeepVision/'
